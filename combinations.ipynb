# %% [markdown]
# # Open to Open [combine]

# %%
# price,macd,twitter,stocktwit
c1 = ['stock_symbol', 'Date', 'Open', 'Close', 'High', 'Low',
       'macd', 'Thursday', 'Tuesday', 'Wednesday', 'price_change', 'Open_t+1', 
       'direction', 
       'tweet_sentiment_count_0', 'tweet_sentiment_count_1', 
       'tweet_sentiment_count_2', 'tweet_sentiment_mean', 
       'stocktwit_sentiment_count_0', 'stocktwit_sentiment_count_1', 
       'stocktwit_sentiment_mean', 
       #'news_sentiment_count_0', 
       #'news_sentiment_count_1', 'news_sentiment_count_2', 
       #'news_sentiment_mean', 
       #'trends', 
       #'Null_value_news',
       'Null_value_stocktwit', 
       'AAPL', 'AMGN', 'AXP', 'BA', 'CAT', 'CRM',
       'CSCO', 'CVX', 'DIS', 'DOW', 'GS', 'HD', 'HON', 'IBM', 'INTC', 'JNJ',
       'JPM', 'KO', 'MCD', 'MMM', 'MSFT', 'NKE', 'PG', 'TRV', 'UNH', 'V', 'VZ',
       'WBA', 'WMT']

# %%
# price,macd,twitter,stocktwit,news
c2 = ['stock_symbol', 'Date', 'Open', 'Close', 'High', 'Low',
       'macd', 'Thursday', 'Tuesday', 'Wednesday', 'price_change', 'Open_t+1', 
       'direction', 
       'tweet_sentiment_count_0', 'tweet_sentiment_count_1', 
       'tweet_sentiment_count_2', 'tweet_sentiment_mean', 
       'stocktwit_sentiment_count_0', 'stocktwit_sentiment_count_1', 
       'stocktwit_sentiment_mean', 
       'news_sentiment_count_0', 
       'news_sentiment_count_1', 'news_sentiment_count_2', 
       'news_sentiment_mean', 
       #'trends', 
       'Null_value_news',
       'Null_value_stocktwit', 
       'AAPL', 'AMGN', 'AXP', 'BA', 'CAT', 'CRM',
       'CSCO', 'CVX', 'DIS', 'DOW', 'GS', 'HD', 'HON', 'IBM', 'INTC', 'JNJ',
       'JPM', 'KO', 'MCD', 'MMM', 'MSFT', 'NKE', 'PG', 'TRV', 'UNH', 'V', 'VZ',
       'WBA', 'WMT']

# %%
# price,macd,twitter,stocktwit,news,trends
c3 = ['stock_symbol', 'Date', 'Open', 'Close', 'High', 'Low',
       'macd', 'Thursday', 'Tuesday', 'Wednesday', 'price_change', 'Open_t+1', 
       'direction', 
       'tweet_sentiment_count_0', 'tweet_sentiment_count_1', 
       'tweet_sentiment_count_2', 'tweet_sentiment_mean', 
       'stocktwit_sentiment_count_0', 'stocktwit_sentiment_count_1', 
       'stocktwit_sentiment_mean', 
       'news_sentiment_count_0', 
       'news_sentiment_count_1', 'news_sentiment_count_2', 
       'news_sentiment_mean', 
       'trends', 
       'Null_value_news',
       'Null_value_stocktwit', 
       'AAPL', 'AMGN', 'AXP', 'BA', 'CAT', 'CRM',
       'CSCO', 'CVX', 'DIS', 'DOW', 'GS', 'HD', 'HON', 'IBM', 'INTC', 'JNJ',
       'JPM', 'KO', 'MCD', 'MMM', 'MSFT', 'NKE', 'PG', 'TRV', 'UNH', 'V', 'VZ',
       'WBA', 'WMT']

# %%
# price,macd,twitter,stocktwit,trends
c4 = ['stock_symbol', 'Date', 'Open', 'Close', 'High', 'Low',
       'macd', 'Thursday', 'Tuesday', 'Wednesday', 'price_change', 'Open_t+1', 
       'direction', 
       'tweet_sentiment_count_0', 'tweet_sentiment_count_1', 
       'tweet_sentiment_count_2', 'tweet_sentiment_mean', 
       'stocktwit_sentiment_count_0', 'stocktwit_sentiment_count_1', 
       'stocktwit_sentiment_mean', 
       #'news_sentiment_count_0', 
       #'news_sentiment_count_1', 'news_sentiment_count_2', 
       #'news_sentiment_mean', 
       'trends', 
       #'Null_value_news',
       'Null_value_stocktwit', 
       'AAPL', 'AMGN', 'AXP', 'BA', 'CAT', 'CRM',
       'CSCO', 'CVX', 'DIS', 'DOW', 'GS', 'HD', 'HON', 'IBM', 'INTC', 'JNJ',
       'JPM', 'KO', 'MCD', 'MMM', 'MSFT', 'NKE', 'PG', 'TRV', 'UNH', 'V', 'VZ',
       'WBA', 'WMT']

# %%
# price,macd,news,trends
c5 = ['stock_symbol', 'Date', 'Open', 'Close', 'High', 'Low',
       'macd', 'Thursday', 'Tuesday', 'Wednesday', 'price_change', 'Open_t+1', 
       'direction', 
       #'tweet_sentiment_count_0', 'tweet_sentiment_count_1', 
       #'tweet_sentiment_count_2', 'tweet_sentiment_mean', 
       #'stocktwit_sentiment_count_0', 'stocktwit_sentiment_count_1', 
       #'stocktwit_sentiment_mean', 
       'news_sentiment_count_0', 
       'news_sentiment_count_1', 'news_sentiment_count_2', 
       'news_sentiment_mean', 
       'trends', 
       'Null_value_news',
       #'Null_value_stocktwit', 
       'AAPL', 'AMGN', 'AXP', 'BA', 'CAT', 'CRM',
       'CSCO', 'CVX', 'DIS', 'DOW', 'GS', 'HD', 'HON', 'IBM', 'INTC', 'JNJ',
       'JPM', 'KO', 'MCD', 'MMM', 'MSFT', 'NKE', 'PG', 'TRV', 'UNH', 'V', 'VZ',
       'WBA', 'WMT']

# %%
# price,macd,twitter
c6 = ['stock_symbol', 'Date', 'Open', 'Close', 'High', 'Low',
       'macd', 'Thursday', 'Tuesday', 'Wednesday', 'price_change', 'Open_t+1', 
       'direction', 
       'tweet_sentiment_count_0', 'tweet_sentiment_count_1', 
       'tweet_sentiment_count_2', 'tweet_sentiment_mean', 
       #'stocktwit_sentiment_count_0', 'stocktwit_sentiment_count_1', 
       #'stocktwit_sentiment_mean', 
       #'news_sentiment_count_0', 
       #'news_sentiment_count_1', 'news_sentiment_count_2', 
       #'news_sentiment_mean', 
       #'trends', 
       #'Null_value_news',
       #'Null_value_stocktwit', 
       'AAPL', 'AMGN', 'AXP', 'BA', 'CAT', 'CRM',
       'CSCO', 'CVX', 'DIS', 'DOW', 'GS', 'HD', 'HON', 'IBM', 'INTC', 'JNJ',
       'JPM', 'KO', 'MCD', 'MMM', 'MSFT', 'NKE', 'PG', 'TRV', 'UNH', 'V', 'VZ',
       'WBA', 'WMT']

# %%
# price,macd,stocktwit
c7 = ['stock_symbol', 'Date', 'Open', 'Close', 'High', 'Low',
       'macd', 'Thursday', 'Tuesday', 'Wednesday', 'price_change', 'Open_t+1', 
       'direction', 
       #'tweet_sentiment_count_0', 'tweet_sentiment_count_1', 
       #'tweet_sentiment_count_2', 'tweet_sentiment_mean', 
       'stocktwit_sentiment_count_0', 'stocktwit_sentiment_count_1', 
       'stocktwit_sentiment_mean', 
       #'news_sentiment_count_0', 
       #'news_sentiment_count_1', 'news_sentiment_count_2', 
       #'news_sentiment_mean', 
       #'trends', 
       #'Null_value_news',
       'Null_value_stocktwit', 
       'AAPL', 'AMGN', 'AXP', 'BA', 'CAT', 'CRM',
       'CSCO', 'CVX', 'DIS', 'DOW', 'GS', 'HD', 'HON', 'IBM', 'INTC', 'JNJ',
       'JPM', 'KO', 'MCD', 'MMM', 'MSFT', 'NKE', 'PG', 'TRV', 'UNH', 'V', 'VZ',
       'WBA', 'WMT']

# %%
# price,macd,news
c8 = ['stock_symbol', 'Date', 'Open', 'Close', 'High', 'Low',
       'macd', 'Thursday', 'Tuesday', 'Wednesday', 'price_change', 'Open_t+1', 
       'direction', 
       #'tweet_sentiment_count_0', 'tweet_sentiment_count_1', 
       #'tweet_sentiment_count_2', 'tweet_sentiment_mean', 
       #'stocktwit_sentiment_count_0', 'stocktwit_sentiment_count_1', 
       #'stocktwit_sentiment_mean', 
       'news_sentiment_count_0', 
       'news_sentiment_count_1', 'news_sentiment_count_2', 
       'news_sentiment_mean', 
       #'trends', 
       'Null_value_news',
       #'Null_value_stocktwit', 
       'AAPL', 'AMGN', 'AXP', 'BA', 'CAT', 'CRM',
       'CSCO', 'CVX', 'DIS', 'DOW', 'GS', 'HD', 'HON', 'IBM', 'INTC', 'JNJ',
       'JPM', 'KO', 'MCD', 'MMM', 'MSFT', 'NKE', 'PG', 'TRV', 'UNH', 'V', 'VZ',
       'WBA', 'WMT']

# %%
# price,macd,trends
c9 = ['stock_symbol', 'Date', 'Open', 'Close', 'High', 'Low',
       'macd', 'Thursday', 'Tuesday', 'Wednesday', 'price_change', 'Open_t+1', 
       'direction', 
       #'tweet_sentiment_count_0', 'tweet_sentiment_count_1', 
       #'tweet_sentiment_count_2', 'tweet_sentiment_mean', 
       #'stocktwit_sentiment_count_0', 'stocktwit_sentiment_count_1', 
       #'stocktwit_sentiment_mean', 
       #'news_sentiment_count_0', 
       #'news_sentiment_count_1', 'news_sentiment_count_2', 
       #'news_sentiment_mean', 
       'trends', 
       #'Null_value_news',
       #'Null_value_stocktwit', 
       'AAPL', 'AMGN', 'AXP', 'BA', 'CAT', 'CRM',
       'CSCO', 'CVX', 'DIS', 'DOW', 'GS', 'HD', 'HON', 'IBM', 'INTC', 'JNJ',
       'JPM', 'KO', 'MCD', 'MMM', 'MSFT', 'NKE', 'PG', 'TRV', 'UNH', 'V', 'VZ',
       'WBA', 'WMT']

# %%
# price,macd
c10 = ['stock_symbol', 'Date', 'Open', 'Close', 'High', 'Low',
       'macd', 'Thursday', 'Tuesday', 'Wednesday', 'price_change', 'Open_t+1', 
       'direction', 
       #'tweet_sentiment_count_0', 'tweet_sentiment_count_1', 
       #'tweet_sentiment_count_2', 'tweet_sentiment_mean', 
       #'stocktwit_sentiment_count_0', 'stocktwit_sentiment_count_1', 
       #'stocktwit_sentiment_mean', 
       #'news_sentiment_count_0', 
       #'news_sentiment_count_1', 'news_sentiment_count_2', 
       #'news_sentiment_mean', 
       #'trends', 
       #'Null_value_news',
       #'Null_value_stocktwit', 
       'AAPL', 'AMGN', 'AXP', 'BA', 'CAT', 'CRM',
       'CSCO', 'CVX', 'DIS', 'DOW', 'GS', 'HD', 'HON', 'IBM', 'INTC', 'JNJ',
       'JPM', 'KO', 'MCD', 'MMM', 'MSFT', 'NKE', 'PG', 'TRV', 'UNH', 'V', 'VZ',
       'WBA', 'WMT']

# %% [markdown]
# #Open to open [separate]

# %%
# price,macd,twitter,stocktwit
c1 = ['stock_symbol', 'Date', 'Open', 'Close', 'High', 'Low',
       'macd', 'Thursday', 'Tuesday', 'Wednesday', 'price_change', 'Open_t+1', 
       'direction', 
       'tweet_sentiment_count_0', 'tweet_sentiment_count_1', 
       'tweet_sentiment_count_2', 'tweet_sentiment_mean', 
       'stocktwit_sentiment_count_0', 'stocktwit_sentiment_count_1', 
       'stocktwit_sentiment_mean', 
       #'news_sentiment_count_0', 
       #'news_sentiment_count_1', 'news_sentiment_count_2', 
       #'news_sentiment_mean', 
       #'trends', 
       #'Null_value_news',
       'Null_value_stocktwit'
       ]

# %%
# price,macd,twitter,stocktwit,news
c2 = ['stock_symbol', 'Date', 'Open', 'Close', 'High', 'Low',
       'macd', 'Thursday', 'Tuesday', 'Wednesday', 'price_change', 'Open_t+1', 
       'direction', 
       'tweet_sentiment_count_0', 'tweet_sentiment_count_1', 
       'tweet_sentiment_count_2', 'tweet_sentiment_mean', 
       'stocktwit_sentiment_count_0', 'stocktwit_sentiment_count_1', 
       'stocktwit_sentiment_mean', 
       'news_sentiment_count_0', 
       'news_sentiment_count_1', 'news_sentiment_count_2', 
       'news_sentiment_mean', 
       #'trends', 
       'Null_value_news',
       'Null_value_stocktwit', 
       ]

# %%
# price,macd,twitter,stocktwit,news,trends
c3 = ['stock_symbol', 'Date', 'Open', 'Close', 'High', 'Low',
       'macd', 'Thursday', 'Tuesday', 'Wednesday', 'price_change', 'Open_t+1', 
       'direction', 
       'tweet_sentiment_count_0', 'tweet_sentiment_count_1', 
       'tweet_sentiment_count_2', 'tweet_sentiment_mean', 
       'stocktwit_sentiment_count_0', 'stocktwit_sentiment_count_1', 
       'stocktwit_sentiment_mean', 
       'news_sentiment_count_0', 
       'news_sentiment_count_1', 'news_sentiment_count_2', 
       'news_sentiment_mean', 
       'trends', 
       'Null_value_news',
       'Null_value_stocktwit', 
       ]

# %%
# price,macd,twitter,stocktwit,trends
c4 = ['stock_symbol', 'Date', 'Open', 'Close', 'High', 'Low',
       'macd', 'Thursday', 'Tuesday', 'Wednesday', 'price_change', 'Open_t+1', 
       'direction', 
       'tweet_sentiment_count_0', 'tweet_sentiment_count_1', 
       'tweet_sentiment_count_2', 'tweet_sentiment_mean', 
       'stocktwit_sentiment_count_0', 'stocktwit_sentiment_count_1', 
       'stocktwit_sentiment_mean', 
       #'news_sentiment_count_0', 
       #'news_sentiment_count_1', 'news_sentiment_count_2', 
       #'news_sentiment_mean', 
       'trends', 
       #'Null_value_news',
       'Null_value_stocktwit', 
       ]

# %%
# price,macd,news,trends
c5 = ['stock_symbol', 'Date', 'Open', 'Close', 'High', 'Low',
       'macd', 'Thursday', 'Tuesday', 'Wednesday', 'price_change', 'Open_t+1', 
       'direction', 
       #'tweet_sentiment_count_0', 'tweet_sentiment_count_1', 
       #'tweet_sentiment_count_2', 'tweet_sentiment_mean', 
       #'stocktwit_sentiment_count_0', 'stocktwit_sentiment_count_1', 
       #'stocktwit_sentiment_mean', 
       'news_sentiment_count_0', 
       'news_sentiment_count_1', 'news_sentiment_count_2', 
       'news_sentiment_mean', 
       'trends', 
       'Null_value_news',
       #'Null_value_stocktwit', 
       ]

# %%
# price,macd,twitter
c6 = ['stock_symbol', 'Date', 'Open', 'Close', 'High', 'Low',
       'macd', 'Thursday', 'Tuesday', 'Wednesday', 'price_change', 'Open_t+1', 
       'direction', 
       'tweet_sentiment_count_0', 'tweet_sentiment_count_1', 
       'tweet_sentiment_count_2', 'tweet_sentiment_mean', 
       #'stocktwit_sentiment_count_0', 'stocktwit_sentiment_count_1', 
       #'stocktwit_sentiment_mean', 
       #'news_sentiment_count_0', 
       #'news_sentiment_count_1', 'news_sentiment_count_2', 
       #'news_sentiment_mean', 
       #'trends', 
       #'Null_value_news',
       #'Null_value_stocktwit', 
       ]

# %%
# price,macd,stocktwit
c7 = ['stock_symbol', 'Date', 'Open', 'Close', 'High', 'Low',
       'macd', 'Thursday', 'Tuesday', 'Wednesday', 'price_change', 'Open_t+1', 
       'direction', 
       #'tweet_sentiment_count_0', 'tweet_sentiment_count_1', 
       #'tweet_sentiment_count_2', 'tweet_sentiment_mean', 
       'stocktwit_sentiment_count_0', 'stocktwit_sentiment_count_1', 
       'stocktwit_sentiment_mean', 
       #'news_sentiment_count_0', 
       #'news_sentiment_count_1', 'news_sentiment_count_2', 
       #'news_sentiment_mean', 
       #'trends', 
       #'Null_value_news',
       'Null_value_stocktwit', 
       ]

# %%
# price,macd,news
c8 = ['stock_symbol', 'Date', 'Open', 'Close', 'High', 'Low',
       'macd', 'Thursday', 'Tuesday', 'Wednesday', 'price_change', 'Open_t+1', 
       'direction', 
       #'tweet_sentiment_count_0', 'tweet_sentiment_count_1', 
       #'tweet_sentiment_count_2', 'tweet_sentiment_mean', 
       #'stocktwit_sentiment_count_0', 'stocktwit_sentiment_count_1', 
       #'stocktwit_sentiment_mean', 
       'news_sentiment_count_0', 
       'news_sentiment_count_1', 'news_sentiment_count_2', 
       'news_sentiment_mean', 
       #'trends', 
       'Null_value_news',
       #'Null_value_stocktwit', 
       ]

# %%
# price,macd,trends
c9 = ['stock_symbol', 'Date', 'Open', 'Close', 'High', 'Low',
       'macd', 'Thursday', 'Tuesday', 'Wednesday', 'price_change', 'Open_t+1', 
       'direction', 
       #'tweet_sentiment_count_0', 'tweet_sentiment_count_1', 
       #'tweet_sentiment_count_2', 'tweet_sentiment_mean', 
       #'stocktwit_sentiment_count_0', 'stocktwit_sentiment_count_1', 
       #'stocktwit_sentiment_mean', 
       #'news_sentiment_count_0', 
       #'news_sentiment_count_1', 'news_sentiment_count_2', 
       #'news_sentiment_mean', 
       'trends', 
       #'Null_value_news',
       #'Null_value_stocktwit', 
       ]

# %%
# price,macd,trends
c10 = ['stock_symbol', 'Date', 'Open', 'Close', 'High', 'Low',
       'macd', 'Thursday', 'Tuesday', 'Wednesday', 'price_change', 'Open_t+1', 
       'direction', 
       #'tweet_sentiment_count_0', 'tweet_sentiment_count_1', 
       #'tweet_sentiment_count_2', 'tweet_sentiment_mean', 
       #'stocktwit_sentiment_count_0', 'stocktwit_sentiment_count_1', 
       #'stocktwit_sentiment_mean', 
       #'news_sentiment_count_0', 
       #'news_sentiment_count_1', 'news_sentiment_count_2', 
       #'news_sentiment_mean', 
       #'trends', 
       #'Null_value_news',
       #'Null_value_stocktwit', 
       ]

# %% [markdown]
# # Open to close [combine]

# %%
# price,macd,twitter,stocktwit
c1 = ['stock_symbol', 'Date', 'Open', 'Close', 'High', 'Low',
       'macd', 'Thursday', 'Tuesday', 'Wednesday', 'price_change', 
       'direction', 
       'tweet_sentiment_count_0', 'tweet_sentiment_count_1', 
       'tweet_sentiment_count_2', 'tweet_sentiment_mean', 
       'stocktwit_sentiment_count_0', 'stocktwit_sentiment_count_1', 
       'stocktwit_sentiment_mean', 
       #'news_sentiment_count_0', 
       #'news_sentiment_count_1', 'news_sentiment_count_2', 
       #'news_sentiment_mean', 
       #'trends', 
       #'Null_value_news',
       'Null_value_stocktwit', 
       'AAPL', 'AMGN', 'AXP', 'BA', 'CAT', 'CRM',
       'CSCO', 'CVX', 'DIS', 'DOW', 'GS', 'HD', 'HON', 'IBM', 'INTC', 'JNJ',
       'JPM', 'KO', 'MCD', 'MMM', 'MSFT', 'NKE', 'PG', 'TRV', 'UNH', 'V', 'VZ',
       'WBA', 'WMT']

# %%
# price,macd,twitter,stocktwit,news
c2 = ['stock_symbol', 'Date', 'Open', 'Close', 'High', 'Low',
       'macd', 'Thursday', 'Tuesday', 'Wednesday', 'price_change', 
       'direction', 
       'tweet_sentiment_count_0', 'tweet_sentiment_count_1', 
       'tweet_sentiment_count_2', 'tweet_sentiment_mean', 
       'stocktwit_sentiment_count_0', 'stocktwit_sentiment_count_1', 
       'stocktwit_sentiment_mean', 
       'news_sentiment_count_0', 
       'news_sentiment_count_1', 'news_sentiment_count_2', 
       'news_sentiment_mean', 
       #'trends', 
       'Null_value_news',
       'Null_value_stocktwit', 
       'AAPL', 'AMGN', 'AXP', 'BA', 'CAT', 'CRM',
       'CSCO', 'CVX', 'DIS', 'DOW', 'GS', 'HD', 'HON', 'IBM', 'INTC', 'JNJ',
       'JPM', 'KO', 'MCD', 'MMM', 'MSFT', 'NKE', 'PG', 'TRV', 'UNH', 'V', 'VZ',
       'WBA', 'WMT']

# %%
# price,macd,twitter,stocktwit,news,trends
c3 = ['stock_symbol', 'Date', 'Open', 'Close', 'High', 'Low',
       'macd', 'Thursday', 'Tuesday', 'Wednesday', 'price_change', 
       'direction', 
       'tweet_sentiment_count_0', 'tweet_sentiment_count_1', 
       'tweet_sentiment_count_2', 'tweet_sentiment_mean', 
       'stocktwit_sentiment_count_0', 'stocktwit_sentiment_count_1', 
       'stocktwit_sentiment_mean', 
       'news_sentiment_count_0', 
       'news_sentiment_count_1', 'news_sentiment_count_2', 
       'news_sentiment_mean', 
       'trends', 
       'Null_value_news',
       'Null_value_stocktwit', 
       'AAPL', 'AMGN', 'AXP', 'BA', 'CAT', 'CRM',
       'CSCO', 'CVX', 'DIS', 'DOW', 'GS', 'HD', 'HON', 'IBM', 'INTC', 'JNJ',
       'JPM', 'KO', 'MCD', 'MMM', 'MSFT', 'NKE', 'PG', 'TRV', 'UNH', 'V', 'VZ',
       'WBA', 'WMT']

# %%
# price,macd,twitter,stocktwit,trends
c4 = ['stock_symbol', 'Date', 'Open', 'Close', 'High', 'Low',
       'macd', 'Thursday', 'Tuesday', 'Wednesday', 'price_change', 
       'direction', 
       'tweet_sentiment_count_0', 'tweet_sentiment_count_1', 
       'tweet_sentiment_count_2', 'tweet_sentiment_mean', 
       'stocktwit_sentiment_count_0', 'stocktwit_sentiment_count_1', 
       'stocktwit_sentiment_mean', 
       #'news_sentiment_count_0', 
       #'news_sentiment_count_1', 'news_sentiment_count_2', 
       #'news_sentiment_mean', 
       'trends', 
       #'Null_value_news',
       'Null_value_stocktwit', 
       'AAPL', 'AMGN', 'AXP', 'BA', 'CAT', 'CRM',
       'CSCO', 'CVX', 'DIS', 'DOW', 'GS', 'HD', 'HON', 'IBM', 'INTC', 'JNJ',
       'JPM', 'KO', 'MCD', 'MMM', 'MSFT', 'NKE', 'PG', 'TRV', 'UNH', 'V', 'VZ',
       'WBA', 'WMT']

# %%
# price,macd,news,trends
c5 = ['stock_symbol', 'Date', 'Open', 'Close', 'High', 'Low',
       'macd', 'Thursday', 'Tuesday', 'Wednesday', 'price_change', 
       'direction', 
       #'tweet_sentiment_count_0', 'tweet_sentiment_count_1', 
       #'tweet_sentiment_count_2', 'tweet_sentiment_mean', 
       #'stocktwit_sentiment_count_0', 'stocktwit_sentiment_count_1', 
       #'stocktwit_sentiment_mean', 
       'news_sentiment_count_0', 
       'news_sentiment_count_1', 'news_sentiment_count_2', 
       'news_sentiment_mean', 
       'trends', 
       'Null_value_news',
       #'Null_value_stocktwit', 
       'AAPL', 'AMGN', 'AXP', 'BA', 'CAT', 'CRM',
       'CSCO', 'CVX', 'DIS', 'DOW', 'GS', 'HD', 'HON', 'IBM', 'INTC', 'JNJ',
       'JPM', 'KO', 'MCD', 'MMM', 'MSFT', 'NKE', 'PG', 'TRV', 'UNH', 'V', 'VZ',
       'WBA', 'WMT']

# %%
# price,macd,twitter
c6 = ['stock_symbol', 'Date', 'Open', 'Close', 'High', 'Low',
       'macd', 'Thursday', 'Tuesday', 'Wednesday', 'price_change', 
       'direction', 
       'tweet_sentiment_count_0', 'tweet_sentiment_count_1', 
       'tweet_sentiment_count_2', 'tweet_sentiment_mean', 
       #'stocktwit_sentiment_count_0', 'stocktwit_sentiment_count_1', 
       #'stocktwit_sentiment_mean', 
       #'news_sentiment_count_0', 
       #'news_sentiment_count_1', 'news_sentiment_count_2', 
       #'news_sentiment_mean', 
       #'trends', 
       #'Null_value_news',
       #'Null_value_stocktwit', 
       'AAPL', 'AMGN', 'AXP', 'BA', 'CAT', 'CRM',
       'CSCO', 'CVX', 'DIS', 'DOW', 'GS', 'HD', 'HON', 'IBM', 'INTC', 'JNJ',
       'JPM', 'KO', 'MCD', 'MMM', 'MSFT', 'NKE', 'PG', 'TRV', 'UNH', 'V', 'VZ',
       'WBA', 'WMT']

# %%
# price,macd,stocktwit
c7 = ['stock_symbol', 'Date', 'Open', 'Close', 'High', 'Low',
       'macd', 'Thursday', 'Tuesday', 'Wednesday', 'price_change', 
       'direction', 
       #'tweet_sentiment_count_0', 'tweet_sentiment_count_1', 
       #'tweet_sentiment_count_2', 'tweet_sentiment_mean', 
       'stocktwit_sentiment_count_0', 'stocktwit_sentiment_count_1', 
       'stocktwit_sentiment_mean', 
       #'news_sentiment_count_0', 
       #'news_sentiment_count_1', 'news_sentiment_count_2', 
       #'news_sentiment_mean', 
       #'trends', 
       #'Null_value_news',
       'Null_value_stocktwit', 
       'AAPL', 'AMGN', 'AXP', 'BA', 'CAT', 'CRM',
       'CSCO', 'CVX', 'DIS', 'DOW', 'GS', 'HD', 'HON', 'IBM', 'INTC', 'JNJ',
       'JPM', 'KO', 'MCD', 'MMM', 'MSFT', 'NKE', 'PG', 'TRV', 'UNH', 'V', 'VZ',
       'WBA', 'WMT']

# %%
# price,macd,news
c8 = ['stock_symbol', 'Date', 'Open', 'Close', 'High', 'Low',
       'macd', 'Thursday', 'Tuesday', 'Wednesday', 'price_change', 
       'direction', 
       #'tweet_sentiment_count_0', 'tweet_sentiment_count_1', 
       #'tweet_sentiment_count_2', 'tweet_sentiment_mean', 
       #'stocktwit_sentiment_count_0', 'stocktwit_sentiment_count_1', 
       #'stocktwit_sentiment_mean', 
       'news_sentiment_count_0', 
       'news_sentiment_count_1', 'news_sentiment_count_2', 
       'news_sentiment_mean', 
       #'trends', 
       'Null_value_news',
       #'Null_value_stocktwit', 
       'AAPL', 'AMGN', 'AXP', 'BA', 'CAT', 'CRM',
       'CSCO', 'CVX', 'DIS', 'DOW', 'GS', 'HD', 'HON', 'IBM', 'INTC', 'JNJ',
       'JPM', 'KO', 'MCD', 'MMM', 'MSFT', 'NKE', 'PG', 'TRV', 'UNH', 'V', 'VZ',
       'WBA', 'WMT']

# %%
# price,macd,trends
c9 = ['stock_symbol', 'Date', 'Open', 'Close', 'High', 'Low',
       'macd', 'Thursday', 'Tuesday', 'Wednesday', 'price_change', 
       'direction', 
       #'tweet_sentiment_count_0', 'tweet_sentiment_count_1', 
       #'tweet_sentiment_count_2', 'tweet_sentiment_mean', 
       #'stocktwit_sentiment_count_0', 'stocktwit_sentiment_count_1', 
       #'stocktwit_sentiment_mean', 
       #'news_sentiment_count_0', 
       #'news_sentiment_count_1', 'news_sentiment_count_2', 
       #'news_sentiment_mean', 
       'trends', 
       #'Null_value_news',
       #'Null_value_stocktwit', 
       'AAPL', 'AMGN', 'AXP', 'BA', 'CAT', 'CRM',
       'CSCO', 'CVX', 'DIS', 'DOW', 'GS', 'HD', 'HON', 'IBM', 'INTC', 'JNJ',
       'JPM', 'KO', 'MCD', 'MMM', 'MSFT', 'NKE', 'PG', 'TRV', 'UNH', 'V', 'VZ',
       'WBA', 'WMT']

# %%
# price,macd,trends
c10 = ['stock_symbol', 'Date', 'Open', 'Close', 'High', 'Low',
       'macd', 'Thursday', 'Tuesday', 'Wednesday', 'price_change', 
       'direction', 
       #'tweet_sentiment_count_0', 'tweet_sentiment_count_1', 
       #'tweet_sentiment_count_2', 'tweet_sentiment_mean', 
       #'stocktwit_sentiment_count_0', 'stocktwit_sentiment_count_1', 
       #'stocktwit_sentiment_mean', 
       #'news_sentiment_count_0', 
       #'news_sentiment_count_1', 'news_sentiment_count_2', 
       #'news_sentiment_mean', 
       #'trends', 
       #'Null_value_news',
       #'Null_value_stocktwit', 
       'AAPL', 'AMGN', 'AXP', 'BA', 'CAT', 'CRM',
       'CSCO', 'CVX', 'DIS', 'DOW', 'GS', 'HD', 'HON', 'IBM', 'INTC', 'JNJ',
       'JPM', 'KO', 'MCD', 'MMM', 'MSFT', 'NKE', 'PG', 'TRV', 'UNH', 'V', 'VZ',
       'WBA', 'WMT']

# %% [markdown]
# # Open to close [separate]

# %%
# price,macd,twitter,stocktwit
c1 = ['stock_symbol', 'Date', 'Open', 'Close', 'High', 'Low',
       'macd', 'Thursday', 'Tuesday', 'Wednesday', 'price_change', 
       'direction', 
       'tweet_sentiment_count_0', 'tweet_sentiment_count_1', 
       'tweet_sentiment_count_2', 'tweet_sentiment_mean', 
       'stocktwit_sentiment_count_0', 'stocktwit_sentiment_count_1', 
       'stocktwit_sentiment_mean', 
       #'news_sentiment_count_0', 
       #'news_sentiment_count_1', 'news_sentiment_count_2', 
       #'news_sentiment_mean', 
       #'trends', 
       #'Null_value_news',
       'Null_value_stocktwit'
       ]

# %%
# price,macd,twitter,stocktwit,news
c2 = ['stock_symbol', 'Date', 'Open', 'Close', 'High', 'Low',
       'macd', 'Thursday', 'Tuesday', 'Wednesday', 'price_change', 
       'direction', 
       'tweet_sentiment_count_0', 'tweet_sentiment_count_1', 
       'tweet_sentiment_count_2', 'tweet_sentiment_mean', 
       'stocktwit_sentiment_count_0', 'stocktwit_sentiment_count_1', 
       'stocktwit_sentiment_mean', 
       'news_sentiment_count_0', 
       'news_sentiment_count_1', 'news_sentiment_count_2', 
       'news_sentiment_mean', 
       #'trends', 
       'Null_value_news',
       'Null_value_stocktwit', 
       ]

# %%
# price,macd,twitter,stocktwit,news,trends
c3 = ['stock_symbol', 'Date', 'Open', 'Close', 'High', 'Low',
       'macd', 'Thursday', 'Tuesday', 'Wednesday', 'price_change',  
       'direction', 
       'tweet_sentiment_count_0', 'tweet_sentiment_count_1', 
       'tweet_sentiment_count_2', 'tweet_sentiment_mean', 
       'stocktwit_sentiment_count_0', 'stocktwit_sentiment_count_1', 
       'stocktwit_sentiment_mean', 
       'news_sentiment_count_0', 
       'news_sentiment_count_1', 'news_sentiment_count_2', 
       'news_sentiment_mean', 
       'trends', 
       'Null_value_news',
       'Null_value_stocktwit', 
       ]

# %%
# price,macd,twitter,stocktwit,trends
c4 = ['stock_symbol', 'Date', 'Open', 'Close', 'High', 'Low',
       'macd', 'Thursday', 'Tuesday', 'Wednesday', 'price_change',  
       'direction', 
       'tweet_sentiment_count_0', 'tweet_sentiment_count_1', 
       'tweet_sentiment_count_2', 'tweet_sentiment_mean', 
       'stocktwit_sentiment_count_0', 'stocktwit_sentiment_count_1', 
       'stocktwit_sentiment_mean', 
       #'news_sentiment_count_0', 
       #'news_sentiment_count_1', 'news_sentiment_count_2', 
       #'news_sentiment_mean', 
       'trends', 
       #'Null_value_news',
       'Null_value_stocktwit', 
       ]

# %%
# price,macd,news,trends
c5 = ['stock_symbol', 'Date', 'Open', 'Close', 'High', 'Low',
       'macd', 'Thursday', 'Tuesday', 'Wednesday', 'price_change',  
       'direction', 
       #'tweet_sentiment_count_0', 'tweet_sentiment_count_1', 
       #'tweet_sentiment_count_2', 'tweet_sentiment_mean', 
       #'stocktwit_sentiment_count_0', 'stocktwit_sentiment_count_1', 
       #'stocktwit_sentiment_mean', 
       'news_sentiment_count_0', 
       'news_sentiment_count_1', 'news_sentiment_count_2', 
       'news_sentiment_mean', 
       'trends', 
       'Null_value_news',
       #'Null_value_stocktwit', 
       ]

# %%
# price,macd,twitter
c6 = ['stock_symbol', 'Date', 'Open', 'Close', 'High', 'Low',
       'macd', 'Thursday', 'Tuesday', 'Wednesday', 'price_change',  
       'direction', 
       'tweet_sentiment_count_0', 'tweet_sentiment_count_1', 
       'tweet_sentiment_count_2', 'tweet_sentiment_mean', 
       #'stocktwit_sentiment_count_0', 'stocktwit_sentiment_count_1', 
       #'stocktwit_sentiment_mean', 
       #'news_sentiment_count_0', 
       #'news_sentiment_count_1', 'news_sentiment_count_2', 
       #'news_sentiment_mean', 
       #'trends', 
       #'Null_value_news',
       #'Null_value_stocktwit', 
       ]

# %%
# price,macd,stocktwit
c7 = ['stock_symbol', 'Date', 'Open', 'Close', 'High', 'Low',
       'macd', 'Thursday', 'Tuesday', 'Wednesday', 'price_change',  
       'direction', 
       #'tweet_sentiment_count_0', 'tweet_sentiment_count_1', 
       #'tweet_sentiment_count_2', 'tweet_sentiment_mean', 
       'stocktwit_sentiment_count_0', 'stocktwit_sentiment_count_1', 
       'stocktwit_sentiment_mean', 
       #'news_sentiment_count_0', 
       #'news_sentiment_count_1', 'news_sentiment_count_2', 
       #'news_sentiment_mean', 
       #'trends', 
       #'Null_value_news',
       'Null_value_stocktwit', 
       ]

# %%
# price,macd,news
c8 = ['stock_symbol', 'Date', 'Open', 'Close', 'High', 'Low',
       'macd', 'Thursday', 'Tuesday', 'Wednesday', 'price_change', 
       'direction', 
       #'tweet_sentiment_count_0', 'tweet_sentiment_count_1', 
       #'tweet_sentiment_count_2', 'tweet_sentiment_mean', 
       #'stocktwit_sentiment_count_0', 'stocktwit_sentiment_count_1', 
       #'stocktwit_sentiment_mean', 
       'news_sentiment_count_0', 
       'news_sentiment_count_1', 'news_sentiment_count_2', 
       'news_sentiment_mean', 
       #'trends', 
       'Null_value_news',
       #'Null_value_stocktwit', 
       ]

# %%
# price,macd,trends
c9 = ['stock_symbol', 'Date', 'Open', 'Close', 'High', 'Low',
       'macd', 'Thursday', 'Tuesday', 'Wednesday', 'price_change',  
       'direction', 
       #'tweet_sentiment_count_0', 'tweet_sentiment_count_1', 
       #'tweet_sentiment_count_2', 'tweet_sentiment_mean', 
       #'stocktwit_sentiment_count_0', 'stocktwit_sentiment_count_1', 
       #'stocktwit_sentiment_mean', 
       #'news_sentiment_count_0', 
       #'news_sentiment_count_1', 'news_sentiment_count_2', 
       #'news_sentiment_mean', 
       'trends', 
       #'Null_value_news',
       #'Null_value_stocktwit', 
       ]

# %%
# price,macd,trends
c10 = ['stock_symbol', 'Date', 'Open', 'Close', 'High', 'Low',
       'macd', 'Thursday', 'Tuesday', 'Wednesday', 'price_change',  
       'direction', 
       #'tweet_sentiment_count_0', 'tweet_sentiment_count_1', 
       #'tweet_sentiment_count_2', 'tweet_sentiment_mean', 
       #'stocktwit_sentiment_count_0', 'stocktwit_sentiment_count_1', 
       #'stocktwit_sentiment_mean', 
       #'news_sentiment_count_0', 
       #'news_sentiment_count_1', 'news_sentiment_count_2', 
       #'news_sentiment_mean', 
       #'trends', 
       #'Null_value_news',
       #'Null_value_stocktwit', 
       ]
